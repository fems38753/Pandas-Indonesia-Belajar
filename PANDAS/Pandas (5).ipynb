# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 5, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  3  2  2  3  3
# 1  2  2  2  4  1
# 2  1  2  4  4  2
# 3  4  4  3  2  4
# 4  3  2  2  1  4
# 5  3  2  3  1  3
# 6  4  3  3  3  4
# 7  4  1  2  4  1
# 8  1  2  4  4  1
# 9  4  3  2  3  3

# %%
df[(df['A'] == 1) | (df['A'] == 3)]
# Out:
#    A  B  C  D  E
# 0  3  2  2  3  3
# 2  1  2  4  4  2
# 4  3  2  2  1  4
# 5  3  2  3  1  3
# 8  1  2  4  4  1

# %%
df[df['A'].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 0  3  2  2  3  3
# 2  1  2  4  4  2
# 4  3  2  2  1  4
# 5  3  2  3  1  3
# 8  1  2  4  4  1

# %%
df[~df['A'].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 1  2  2  2  4  1
# 3  4  4  3  2  4
# 6  4  3  3  3  4
# 7  4  1  2  4  1
# 9  4  3  2  3  3
